# %%
using PyPlot
plot(rand(10))

savefig("my_plot1.pdf")
savefig("my_plot1.png")
savefig("my_plot1.jpg")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f9b24071f60>)

# %%
using Plots; 
pyplot()
x=range(-2,stop=2,length=100)
y=range(sqrt(2),stop=2,length=100)
f(x,y) = x*y-x-y+1
plot(x,y,f,st=:surface,camera=(-30,30))
savefig("plot3d1")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc4e7f81ef0>)
